# %% [markdown]
# # 패키지 임포트

# %%
from C110_01_collecting_functions import *

import numpy
import pandas
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
# %matplotlib inline
plt.rcParams['font.size'] = 20
plt.rcParams["figure.figsize"] = (50, 10)
plt.rcParams['lines.linewidth'] = 5
plt.rcParams["axes.grid"] = True

# %%
# %%html
# <style>
#     table { display: inline-block }
#     .rendered_html td, .rendered_html th { text-align: left; }
# </style>
# Out:
# <style>
#     table { display: inline-block }
#     .rendered_html td, .rendered_html th { text-align: left; }
# </style>

# %% [markdown]
# # 코스피 지수 수집

# %%
df = save_kospi_and_kosdaq('KOSPI')
display(df)
# Out:
# [2022/01/02 23:22:16]:[https://finance.naver.com/sise/sise_index_day.nhn?code=KOSPI&page=1]
# [2022/01/02 23:22:18]:[save_kospi_and_kosdaq KOSPI Start: 20211223 ,Finish: 20211230 0 (6, 6)]
# [2022/01/02 23:22:18]:[https://finance.naver.com/sise/sise_index_day.nhn?code=KOSPI&page=2]
# [2022/01/02 23:22:21]:[save_kospi_and_kosdaq KOSPI Start: 20211215 ,Finish: 20211230 6 (12, 6)]
# [2022/01/02 23:22:21]:[https://finance.naver.com/sise/sise_index_day.nhn?code=KOSPI&page=3]
# [2022/01/02 23:22:23]:[save_kospi_and_kosdaq KOSPI Start: 20211207 ,Finish: 20211230 12 (18, 6)]
# [2022/01/02 23:22:23]:[https://finance.naver.com/sise/sise_index_day.nhn?code=KOSPI&page=4]
# [2022/01/02 23:22:25]:[save_kospi_and_kosdaq KOSPI Start: 20211129 ,Finish: 20211230 18 (24, 6)]
# [2022/01/02 23:22:25]:[https://finance.naver.com/sise/sise_index_day.nhn?code=KOSPI&page=5]
# [2022/01/02 23:22:27]:[save_kospi_and_kosdaq KOSPI Start: 20211119 ,Finish: 20211230 24 (30, 6)]
# [2022/01/02 23:22:27]:[https://finance.naver.com/sise/sise_index_day.nhn?code=KOSPI&page=6]
# [2022/01/02 23:22:29]:[save_kospi_and_kosdaq KOSPI Start: 20211111 ,Finish: 20211230 30 (36, 6)]
# [2022/01/02 23:22:29]:[https://finance.naver.com/sise/sise_index_day.nhn?code=KOSPI&page=7]
# [2022/01/02 23:22:31]:[save_kospi_and_kosdaq KOSPI Start: 20211103 ,Finish: 20211230 36 (42, 6)]
# [2022/01/02 23:22:31]:[https://finance.naver.com/sise/sise_index_day.nhn?code=KOSPI&page=8]
# [2022/01/02 23:22:34]:[save_kospi_and_kosdaq KOSPI Start: 20211026 ,Finish: 20211230 42 (48, 6)]
# [2022/01/02 23:22:34]:[https://finance.naver.com/sise/sise_index_day.nhn?code=KOSPI&page=9]
# [2022/01/02 23:22:36]:[save_kospi_and_kosdaq KOSPI Start: 20211018 ,Finish: 20211230 48 (54, 6)]
#     eod_date item_code  price_close  trade_amount   diff  rate
# 0   20211230     KOSPI      2977.65        461038  15.64 -0.52
# 1   20211229     KOSPI      2993.29        545831  26.95 -0.89
# 2   20211228     KOSPI      3020.24        607046  20.69  0.69
# 3   20211227     KOSPI      2999.55        475363  12.88 -0.43
# 4   20211224     KOSPI      3012.43        537548  14.26  0.48
# 5   20211223     KOSPI      2998.17        483838  13.69  0.46
# 6   20211222     KOSPI      2984.48        461755   9.45  0.32
# 7   20211221     KOSPI      2975.03        410979  12.03  0.41
# 8   20211220     KOSPI      2963.00        377584  54.73 -1.81
# 9   20211217     KOSPI      3017.73        451824  11.32  0.38
# 10  20211216     KOSPI      3006.41        402825  17.02  0.57
# 11  20211215     KOSPI      2989.39        432874   1.44  0.05
# 12  20211214     KOSPI      2987.95        581569  13.71 -0.46
# 13  20211213     KOSPI      3001.66        375828   8.57 -0.28
# 14  20211210     KOSPI      3010.23        451599  19.34 -0.64
# 15  20211209     KOSPI      3029.57        513445  27.77  0.93
# 16  20211208     KOSPI      3001.80        488246  10.08  0.34
# 17  20211207     KOSPI      2991.72        541370  18.47  0.62
# 18  20211206     KOSPI      2973.25        479907   4.92  0.17
# 19  20211203     KOSPI      2968.33        486749  23.06  0.78
# 20  20211202     KOSPI      2945.27        534461  45.55  1.57
# 21  20211201     KOSPI      2899.72        563927  60.71  2.14
# 22  20211130     KOSPI      2839.01        983556  70.31 -2.42
# 23  20211129     KOSPI      2909.32        844400  27.12 -0.92
# 24  20211126     KOSPI      2936.44        595597  43.83 -1.47
# 25  20211125     KOSPI      2980.27        595969  14.02 -0.47
# 26  20211124     KOSPI      2994.29        556640   3.04 -0.10
# 27  20211123     KOSPI      2997.33        524233  15.92 -0.53
# 28  20211122     KOSPI      3013.25        530959  42.23  1.42
# 29  20211119     KOSPI      2971.02        657093  23.64  0.80
# 30  20211118     KOSPI      2947.38        541652  15.04 -0.51
# 31  20211117     KOSPI      2962.42        541489  34.79 -1.16
# 32  20211116     KOSPI      2997.21        579646   2.31 -0.08
# 33  20211115     KOSPI      2999.52        639395  30.72  1.03
# 34  20211112     KOSPI      2968.80        665733  43.88  1.50
# 35  20211111     KOSPI      2924.92        572859   5.25 -0.18
# 36  20211110     KOSPI      2930.17        570931  32.29 -1.09
# 37  20211109     KOSPI      2962.46        708773   2.26  0.08
# 38  20211108     KOSPI      2960.20        560205   9.07 -0.31
# 39  20211105     KOSPI      2969.27        688027  13.95 -0.47
# 40  20211104     KOSPI      2983.22        772023   7.51  0.25
# 41  20211103     KOSPI      2975.71        658648  37.78 -1.25
# 42  20211102     KOSPI      3013.49        525853  34.55  1.16
# 43  20211101     KOSPI      2978.94        475382   8.26  0.28
# 44  20211029     KOSPI      2970.68        545833  38.87 -1.29
# 45  20211028     KOSPI      3009.55        617256  15.94 -0.53
# 46  20211027     KOSPI      3025.49        607875  23.59 -0.77
# 47  20211026     KOSPI      3049.08        564559  28.54  0.94
# 48  20211025     KOSPI      3020.54        791795  14.38  0.48
# 49  20211022     KOSPI      3006.16        695272   1.17 -0.04
# 50  20211021     KOSPI      3007.33        887369   5.80 -0.19
# 51  20211020     KOSPI      3013.13        680326  15.91 -0.53
# 52  20211019     KOSPI      3029.04        845703  22.36  0.74
# 53  20211018     KOSPI      3006.68        926369   8.38 -0.28

# %%
df['datetime'] = pandas.to_datetime(df['eod_date'], format='%Y%m%d')
df_plot = df.set_index(['datetime'])
df_plot = df_plot[['price_close']]
df_plot.plot()
# Out:
# <AxesSubplot:xlabel='datetime'>
